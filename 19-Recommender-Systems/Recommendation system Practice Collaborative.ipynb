# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Get the Data

# %%
column_names = ['user_id', 'item_id', 'rating', 'timestamp']
df = pd.read_csv('u.data',names=column_names,sep='\t')

# %%
df.head()
# Out:
#    user_id  item_id  rating  timestamp
# 0        0       50       5  881250949
# 1        0      172       5  881250949
# 2        0      133       1  881250949
# 3      196      242       3  881250949
# 4      186      302       3  891717742

# %%
movie_titles = pd.read_csv('Movie_Id_Titles')
movie_titles.head()
# Out:
#    item_id              title
# 0        1   Toy Story (1995)
# 1        2   GoldenEye (1995)
# 2        3  Four Rooms (1995)
# 3        4  Get Shorty (1995)
# 4        5     Copycat (1995)

# %%
df = pd.merge(df,movie_titles,on='item_id')
df.head()
# Out:
#    user_id  item_id  rating  timestamp             title
# 0        0       50       5  881250949  Star Wars (1977)
# 1      290       50       5  880473582  Star Wars (1977)
# 2       79       50       4  891271545  Star Wars (1977)
# 3        2       50       5  888552084  Star Wars (1977)
# 4        8       50       5  879362124  Star Wars (1977)

# %%
df.groupby('title').head()
# Out:
#         user_id  item_id  rating  timestamp  \
# 0             0       50       5  881250949
# 1           290       50       5  880473582
# 2            79       50       4  891271545
# 3             2       50       5  888552084
# 4             8       50       5  879362124
# ...         ...      ...     ...        ...
# 99998       840     1674       4  891211682
# 99999       655     1640       3  888474646
# 100000      655     1637       3  888984255
# 100001      655     1630       3  887428735
# 100002      655     1641       3  887427810
#
#                                                     title
# 0                                        Star Wars (1977)
# 1                                        Star Wars (1977)
# 2                                        Star Wars (1977)
# 3                                        Star Wars (1977)
# 4                                        Star Wars (1977)
# ...                                                   ...
# ...

# %% [markdown]
# ## import data visualization libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
ls = pd.DataFrame(df.groupby('title')['rating'].mean().sort_values(ascending=False))
ls.head()
# Out:
#                                             rating
# title
# They Made Me a Criminal (1939)                 5.0
# Marlene Dietrich: Shadow and Light (1996)      5.0
# Saint of Fort Washington, The (1993)           5.0
# Someone Else's America (1995)                  5.0
# Star Kid (1997)                                5.0

# %%
ls['num of ratings'] = df.groupby('title')['rating'].count()

# %%
ls['num of ratings'].hist(bins=70)
ls
# Out:
#                                               rating  num of ratings
# title
# They Made Me a Criminal (1939)                   5.0               1
# Marlene Dietrich: Shadow and Light (1996)        5.0               1
# Saint of Fort Washington, The (1993)             5.0               2
# Someone Else's America (1995)                    5.0               1
# Star Kid (1997)                                  5.0               3
# ...                                              ...             ...
# Eye of Vichy, The (Oeil de Vichy, L') (1993)     1.0               1
# King of New York (1990)                          1.0               1
# Touki Bouki (Journey of the Hyena) (1973)        1.0               1
# Bloody Child, The (1996)                         1.0               1
# Crude Oasis, The (1995)                          1.0               1
#
# [1664 rows x 2 columns]

# %%
moviemat = df.pivot_table(index='user_id',columns='title',values='rating')

# %%
moviemat
# Out:
# title    'Til There Was You (1997)  1-900 (1994)  101 Dalmatians (1996)  \
# user_id
# 0                              NaN           NaN                    NaN
# 1                              NaN           NaN                    2.0
# 2                              NaN           NaN                    NaN
# 3                              NaN           NaN                    NaN
# 4                              NaN           NaN                    NaN
# ...                            ...           ...                    ...
# 939                            NaN           NaN                    NaN
# 940                            NaN           NaN                    NaN
# 941                            NaN           NaN                    NaN
# 942                            NaN           NaN                    NaN
# 943                            NaN           NaN                    NaN
#
# title    12 Angry Men (1957)  187 (1997)  2 Days in the Valley (1996)  \
# user_id
# ...

# %%
ls.sort_values('num of ratings',ascending=False).head()
# Out:
#                              rating  num of ratings
# title
# Star Wars (1977)           4.359589             584
# Contact (1997)             3.803536             509
# Fargo (1996)               4.155512             508
# Return of the Jedi (1983)  4.007890             507
# Liar Liar (1997)           3.156701             485

# %%
starwars_user_rating = moviemat['Star Wars (1977)']

# %%
coerr_with_starwars = moviemat.corrwith(starwars_user_rating)
# Out:
# C:\Users\VISHNU\AppData\Roaming\Python\Python39\site-packages\numpy\lib\function_base.py:2821: RuntimeWarning: Degrees of freedom <= 0 for slice
#   c = cov(x, y, rowvar, dtype=dtype)
# C:\Users\VISHNU\AppData\Roaming\Python\Python39\site-packages\numpy\lib\function_base.py:2680: RuntimeWarning: divide by zero encountered in true_divide
#   c *= np.true_divide(1, fact)

# %%
similar_to_starwars = pd.DataFrame(data=coerr_with_starwars,columns=['correlation'])

# %%
similar_to_starwars.dropna(inplace=True)

# %%
similar_to_starwars.sort_values('correlation',ascending=False).head()
# Out:
#                      correlation
# title
# Hollow Reed (1996)           1.0
# Commandments (1997)          1.0
# Cosi (1996)                  1.0
# No Escape (1994)             1.0
# Stripes (1981)               1.0

# %%
similar_to_starwars = similar_to_starwars.join(other=ls,on='title')

# %%
similar_to_starwars[similar_to_starwars['num of ratings']>100].sort_values('correlation',ascending=False).head()
# Out:
#                                                     correlation    rating  \
# title
# Star Wars (1977)                                       1.000000  4.359589
# Empire Strikes Back, The (1980)                        0.748353  4.206522
# Return of the Jedi (1983)                              0.672556  4.007890
# Raiders of the Lost Ark (1981)                         0.536117  4.252381
# Austin Powers: International Man of Mystery (1997)     0.377433  3.246154
#
#                                                     num of ratings
# title
# Star Wars (1977)                                               584
# Empire Strikes Back, The (1980)                                368
# Return of the Jedi (1983)                                      507
# Raiders of the Lost Ark (1981)                                 420
# Austin Powers: International Man of Mystery (1997)             130
